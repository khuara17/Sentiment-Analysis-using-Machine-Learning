# %%
import numpy as np
import pandas as pd
import re,csv
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
#from sklearn.externals import joblib

# %%
def import_tweets(filename, header = None):
    #import data from csv file via pandas library
    tweet_dataset = pd.read_csv(filename, encoding = 'ISO-8859-1', header = header)
    tweet_dataset.columns = ['sentiment','id','date','flag','user','text']
    #delete 3 columns: flags,id,user, as they are not required for analysis
    for i in ['flag','id','user','date']: del tweet_dataset[i] # or tweet_dataset = tweet_dataset.drop(["id","user","date","user"], axis = 1)
    #in dataset, positive = 4, negative = 0; So change positive to 1
    tweet_dataset.sentiment = tweet_dataset.sentiment.replace(4,1)
    return tweet_dataset

def preprocess_tweet(tweet):
        #Preprocess the text in a single tweet
        #arguments: tweet = a single tweet in form of string 
        #convert the tweet to lower case
        tweet.lower()
        #convert all urls to sting "URL"
        tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL',tweet)
        #convert all @username to "AT_USER"
        tweet = re.sub('@[^\s]+','AT_USER', tweet)
        #correct all multiple white spaces to a single white space
        tweet = re.sub('[\s]+', ' ', tweet)
        #convert "#topic" to just "topic"
        tweet = re.sub(r'#([^\s]+)', r'\1', tweet)
        return tweet
    
def analysis(user_ip):
    ip = preprocess_tweet(user_ip)
    ip = np.array([user_ip])
    vector = tfv.transform(ip)
    sentiment = classifier_n.predict(vector)
    if(sentiment == 0):
        print("The Sentence is NEGATIVE")
    else:
        print("The Sentence is POSITIVE")

# %%
#importing csv file
#tweet_dataset = import_tweets("book1.csv")
tweet_dataset = import_tweets("training.1600000.processed.noemoticon.csv")

# %%
#preprocessing and labeling
tweet_dataset['text'] = tweet_dataset['text'].apply(preprocess_tweet)
data = np.array(tweet_dataset['text'])
label = np.array(tweet_dataset.sentiment)

# %%
#features extraction
from sklearn.feature_extraction.text import TfidfVectorizer
tfv = TfidfVectorizer(sublinear_tf=True, stop_words = "english") # we need to give proper stopwords list for better performance

# %%
features = tfv.fit_transform(data)

# %%
#spliting data for training and testing
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C=1.)
    
#fit model to data
classifier = model.fit(features, label)
# Out:
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
open_classifier = open('logistic_regression.pickle','wb')
pickle.dump(classifier, open_classifier)
open_classifier.close()

# %%
load_classifier = open('logistic_regression.pickle','rb')
classifier_n = pickle.load(load_classifier)
load_classifier.close()

# %%
predictions = classifier_n.predict(X_test)
#print(predictions)
score = classifier_n.score(X_test, y_test)
print(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5fa3a840cb91> in <module>
# ----> 1 predictions = classifier_n.predict(X_test)
#       2 #print(predictions)
#       3 score = classifier_n.score(X_test, y_test)
#       4 print(score)
#
# NameError: name 'X_test' is not defined

# %%
predictions = model.predict(X_test)
#print(predictions)
score = model.score(X_test, y_test)
print(score)
# Out:
# 0.801984375

# %%
#checking on user data            
n = input("enter the sentence :")
analysis(n)
# Out:
# enter the sentence :It is so buttery smooth and insanely fast that i don't have words to describe whole experience... Just buy it you won't regret... Its better than OnePlus 7 Pro.
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-13-9bb50355af20> in <module>
#       1 #checking on user data
#       2 n = input("enter the sentence :")
# ----> 3 analysis(n)
#
# <ipython-input-12-06ad79aed57f> in analysis(user_ip)
#      27     ip = preprocess_tweet(user_ip)
#      28     ip = np.array([user_ip])
# ---> 29     vector = tfv.transform(ip)
#      30     sentiment = classifier_n.predict(vector)
#      31     if(sentiment == 0):
#
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents, copy)
#    1678         check_is_fitted(self, '_tfidf', 'The tfidf vector is not fitted')
#    1679
# -> 1680         X = super().transform(raw_documents)
#    1681         return self._tfidf.transform(X, copy=False)
#    1682
#
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents)
#    1107             self._validate_vocabulary()
#    1108
# -> 1109         self._check_vocabulary()
#    1110
#    1111         # use the same matrix-building strategy as fit_transform
#
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\feature_extraction\text.py in _check_vocabulary(self)
#     387         """Check if vocabulary is empty or missing (not fit-ed)"""
#     388         msg = "%(name)s - Vocabulary wasn't fitted."
# --> 389         check_is_fitted(self, 'vocabulary_', msg=msg),
#     390
#     391         if len(self.vocabulary_) == 0:
#
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: TfidfVectorizer - Vocabulary wasn't fitted.

# %%
    
#     #importing csv file
#     tweet_dataset = import_tweets("book1.csv")
    
#     #preprocessing and labeling
#     tweet_dataset['text'] = tweet_dataset['text'].apply(preprocess_tweet)
#     data = np.array(tweet_dataset['text'])
#     label = np.array(tweet_dataset.sentiment)
    
#     #features extraction
#     from sklearn.feature_extraction.text import TfidfVectorizer
#     tfv = TfidfVectorizer(sublinear_tf=True, stop_words = "english") # we need to give proper stopwords list for better performance
#     features = tfv.fit_transform(data)
    
#     #features = feature_extraction(data, method = "tfidf") #1600000x288571 sparse matrix of type 'numpy.float64
    
#     #spliting data for training and testing
#     X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.2)
    
#     #training the model
#     #model = train_classifier(X_train, y_train, X_test, y_test, "logistic_regression")
    
#     from sklearn.linear_model import LogisticRegression
#     model = LogisticRegression(C=1.)
    
#     #fit model to data
#     classifier = model.fit(features, label)
#     predictions = model.predict(X_test)
#     #print(predictions)
#     score = model.score(X_test, y_test)
#     print(score)
    
#     #checking on user data            
#     n = input("enter the sentence :")
#     analysis(n)
# Out:
# c:\users\pmd\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8228915662650602
# enter the sentence :I don't shopping often and I never Signed for Prime membership and was surprised to see being charged $8.39. I had never even opened to see what they offer. How I became a member? I had to unsubscribe. People be aware.
# The Sentence is NEGATIVE
